# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("EV_data1.csv")

#  View basic info
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB
# None
# Brand              0
# Model              0
# AccelSec           0
# ...

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("EV_data_encoded.csv")

#  View basic info
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    int64
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    float64
#  7   RapidCharge      103 non-null    int64
#  8   PowerTrain       103 non-null    int64
#  9   PlugType         103 non-null    int64
#  10  BodyStyle        103 non-null    int64
#  11  Segment          103 non-null    int64
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(2), int64(11), object(1)
# memory usage: 11.4+ KB
# None
# Brand              0
# Model              0
# AccelSec           0
# ...

# %%
copy_data=df.copy()
X = df.drop(columns=["Range_Km"])
y = df["Range_Km"]

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      Brand                            Model  AccelSec  TopSpeed_KmH  Range_Km  \
# 0       30    Model 3 Long Range Dual Motor       4.6           233       450
# 1       31                        ID.3 Pure      10.0           160       270
# 2       23                                2       4.7           210       400
# 3        2                             iX3        6.8           180       360
# 4        9                               e        9.5           145       170
# ..     ...                              ...       ...           ...       ...
# 98      20                      Ariya 63kWh       7.5           160       330
# 99       1    e-tron S Sportback 55 quattro       4.5           210       335
# 100     20              Ariya e-4ORCE 63kWh       5.9           200       325
# 101     20  Ariya e-4ORCE 87kWh Performance       5.1           200       375
# 102      3                M-Byte 95 kWh 2WD       7.5           190       400
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Model'] = le.fit_transform(df['Model'])

# %%
df.describe()
# Out:
#             Brand       Model    AccelSec  TopSpeed_KmH    Range_Km  \
# count  103.000000  103.000000  103.000000    103.000000  103.000000
# mean    18.058252   50.864078    7.396117    179.194175  338.786408
# std     10.546652   29.674393    3.017430     43.573030  126.014444
# min      0.000000    0.000000    2.100000    123.000000   95.000000
# 25%      8.500000   25.500000    5.100000    150.000000  250.000000
# 50%     20.000000   51.000000    7.300000    160.000000  340.000000
# 75%     27.500000   76.500000    9.000000    200.000000  400.000000
# max     32.000000  101.000000   22.400000    410.000000  970.000000
#
#        Efficiency_WhKm  FastCharge_KmH  RapidCharge  PowerTrain    PlugType  \
# count       103.000000      103.000000   103.000000  103.000000  103.000000
# mean        189.165049      434.563107     0.951456    0.844660    1.922330
# std          29.566839      219.660061     0.215963    0.789108    0.388292
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    int64
#  1   Model            103 non-null    int64
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    float64
#  7   RapidCharge      103 non-null    int64
#  8   PowerTrain       103 non-null    int64
#  9   PlugType         103 non-null    int64
#  10  BodyStyle        103 non-null    int64
#  11  Segment          103 non-null    int64
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(2), int64(12)
# memory usage: 11.4 KB
# None

# %%
c
# Out:
# Train: (82, 13) Test: (21, 13)

# %%
import matplotlib.pyplot as plt

df[['Range_Km', 'AccelSec', 'TopSpeed_KmH', 'PriceEuro']].boxplot(figsize=(10,6))
plt.title("Outlier check")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model = LinearRegression()
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)

# %%
import numpy as np
import pandas as pd

# Step 1: Ask user to enter features
print("Enter your car details below 👇")

Brand = int(input("Brand (numeric code): "))
Model = int(input("Model (encoded number): "))
AccelSec = float(input("Acceleration (0-100 km/h in seconds): "))
TopSpeed_KmH = int(input("Top Speed (km/h): "))
Efficiency_WhKm = int(input("Efficiency (Wh/km): "))
FastCharge_KmH = float(input("Fast Charge Speed (km/h): "))
RapidCharge = int(input("Rapid Charge (1 for yes, 0 for no): "))
PowerTrain = int(input("Power Train (encoded number): "))
PlugType = int(input("Plug Type (encoded number): "))
BodyStyle = int(input("Body Style (encoded number): "))
Segment = int(input("Segment (encoded number): "))
Seats = int(input("Seats: "))
PriceEuro = int(input("Price (Euro): "))

# Step 2: Put into DataFrame in same order as training data
new_data = pd.DataFrame([[Brand, Model, AccelSec, TopSpeed_KmH,
                          Efficiency_WhKm, FastCharge_KmH, RapidCharge,
                          PowerTrain, PlugType, BodyStyle, Segment, Seats, PriceEuro]],
                        columns=X.columns)

# Step 3: Apply same scaling as training
new_scaled = scaler.transform(new_data)

# Step 4: Predict using the trained model
predicted_range = model.predict(new_scaled)

# Step 5: Show result
print(f"\n🚗 Estimated Range for this EV: {predicted_range[0]:.2f} km")
# Out:
# Enter your car details below 👇
# Brand (numeric code):  2
# Model (encoded number):  2
# Acceleration (0-100 km/h in seconds):  56
# Top Speed (km/h):  45
# Efficiency (Wh/km):  23
# Fast Charge Speed (km/h):  23
# Rapid Charge (1 for yes, 0 for no):  1
# Power Train (encoded number):  23
# Plug Type (encoded number):  3
# Body Style (encoded number):  3
# Segment (encoded number):  3
# Seats:  5
# Price (Euro):  65443
# 🚗 Estimated Range for this EV: 756.16 km

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# 1️⃣ R² Score (Coefficient of Determination)
r2 = r2_score(y_test, y_pred)

# 2️⃣ Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# 3️⃣ Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# 4️⃣ Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("📊 Model Performance Metrics:")
print(f"R² Score: {r2:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# 📊 Model Performance Metrics:
# R² Score: 0.3082
# Mean Absolute Error (MAE): 71.37
# Mean Squared Error (MSE): 9189.14
# Root Mean Squared Error (RMSE): 95.86
